# %%
import pandas as pd
import numpy as np

# %%
df_to = pd.read_excel("toronto-FSAs.xlsx",header=0,names=["Postcode","Borough","Neighbourhood"])

# %%
df_to.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 3 columns):
# Postcode         288 non-null object
# Borough          288 non-null object
# Neighbourhood    288 non-null object
# dtypes: object(3)
# memory usage: 6.8+ KB

# %%
df_to1 = df_to[df_to["Borough"] != "Not assigned "]

# %%
df_to1.head()
# Out:
#   Postcode            Borough     Neighbourhood
# 2     M3A         North York          Parkwoods
# 3     M4A         North York   Victoria Village
# 4     M5A   Downtown Toronto       Harbourfront
# 5     M5A   Downtown Toronto        Regent Park
# 6     M6A         North York   Lawrence Heights

# %%
#df_to2 = df_to1.sort_values('Postcode')

# %%
#df_to2

# %%
df_to2 = df_to1.groupby(['Postcode','Borough'], as_index=False, sort=False).agg(','.join)

# %%
df_to2.head()
# Out:
#   Postcode            Borough                    Neighbourhood
# 0     M3A         North York                         Parkwoods
# 1     M4A         North York                  Victoria Village
# 2     M5A   Downtown Toronto          Harbourfront,Regent Park
# 3     M6A         North York   Lawrence Heights,Lawrence Manor
# 4     M7A       Queen's Park                      Not assigned

# %%
df_to2.replace('Not assigned', 'Queen\'s Park', inplace = True)

# %%
df_to2.head(11)
# Out:
#    Postcode            Borough                    Neighbourhood
# 0      M3A         North York                         Parkwoods
# 1      M4A         North York                  Victoria Village
# 2      M5A   Downtown Toronto          Harbourfront,Regent Park
# 3      M6A         North York   Lawrence Heights,Lawrence Manor
# 4      M7A       Queen's Park                      Queen's Park
# 5      M9A          Etobicoke                  Islington Avenue
# 6      M1B        Scarborough                     Rouge,Malvern
# 7      M3B         North York                   Don Mills North
# 8      M4B          East York    Woodbine Gardens,Parkview Hill
# 9      M5B   Downtown Toronto           Ryerson,Garden District
# 10     M6B         North York                         Glencairn

# %%
df_geo = pd.read_csv("Geospatial_Coordinates.csv",header=0,names=["Postcode","Latitude","Longitude"])

# %%
df_geo.head()
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %%
df_to2.head()
# Out:
#   Postcode            Borough                    Neighbourhood
# 0     M3A         North York                         Parkwoods
# 1     M4A         North York                  Victoria Village
# 2     M5A   Downtown Toronto          Harbourfront,Regent Park
# 3     M6A         North York   Lawrence Heights,Lawrence Manor
# 4     M7A       Queen's Park                      Queen's Park

# %%
df_to2['Postcode']=df_geo['Postcode'].astype('str')
df_geo['Postcode']=df_geo['Postcode'].astype('str')

# %%
df_geo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 3 columns):
# Postcode     103 non-null object
# Latitude     103 non-null object
# Longitude    103 non-null object
# dtypes: object(3)
# memory usage: 2.5+ KB

# %%
df_to_geo=pd.merge(df_to2,df_geo,on = 'Postcode')

# %%
df_to_geo
# Out:
#     Postcode            Borough  \
# 0        M1B        North York
# 1        M1C        North York
# 2        M1E  Downtown Toronto
# 3        M1G        North York
# 4        M1H      Queen's Park
# 5        M1J         Etobicoke
# 6        M1K       Scarborough
# 7        M1L        North York
# 8        M1M         East York
# 9        M1N  Downtown Toronto
# 10       M1P        North York
# 11       M1R         Etobicoke
# 12       M1S       Scarborough
# 13       M1T        North York
# 14       M1V         East York
# 15       M1W  Downtown Toronto
# 16       M1X              York
# 17       M2H         Etobicoke
# 18       M2J       Scarborough
# 19       M2K      East Toronto
# 20       M2L  Downtown Toronto
# 21       M2M              York
# 22       M2N       Scarborough
# 23       M2P         East York
# 24       M2R  Downtown Toronto
# 25       M3A  Downtown Toronto
# 26       M3B       Scarborough
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J         East York
# ..       ...                ...
# 73       M6C   Central Toronto
# 74       M6E   Central Toronto
# 75       M6G      West Toronto
# 76       M6H       Mississauga
# 77       M6J         Etobicoke
# 78       M6K       Scarborough
# 79       M6L   Central Toronto
# 80       M6M  Downtown Toronto
# 81       M6N      West Toronto
# 82       M6P       Scarborough
# 83       M6R   Central Toronto
# 84       M6S  Downtown Toronto
# 85       M7A       Scarborough
# 86       M7R   Central Toronto
# 87       M7Y  Downtown Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X       Scarborough
# 91       M8Y  Downtown Toronto
# 92       M8Z  Downtown Toronto
# 93       M9A         Etobicoke
# 94       M9B         Etobicoke
# 95       M9C       Scarborough
# 96       M9L  Downtown Toronto
# 97       M9M  Downtown Toronto
# 98       M9N         Etobicoke
# 99       M9P  Downtown Toronto
# 100      M9R      East Toronto
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                          Neighbourhood Latitude Longitude
# 0                                            Parkwoods  43.8067  -79.1944
# 1                                     Victoria Village  43.7845  -79.1605
# 2                             Harbourfront,Regent Park  43.7636  -79.1887
# 3                      Lawrence Heights,Lawrence Manor   43.771  -79.2169
# 4                                         Queen's Park  43.7731  -79.2395
# 5                                     Islington Avenue  43.7447  -79.2395
# 6                                        Rouge,Malvern  43.7279   -79.262
# 7                                      Don Mills North  43.7111  -79.2846
# 8                       Woodbine Gardens,Parkview Hill  43.7163  -79.2395
# 9                              Ryerson,Garden District  43.6927  -79.2648
# 10                                           Glencairn  43.7574  -79.2733
# 11   Cloverdale,Islington,Martin Grove,Princess Gar...  43.7501  -79.2958
# 12                Highland Creek,Rouge Hill,Port Union  43.7942   -79.262
# 13                     Flemingdon Park,Don Mills South  43.7816  -79.3043
# 14                                    Woodbine Heights  43.8153  -79.2846
# 15                                      St. James Town  43.7995  -79.3184
# 16                                  Humewood-Cedarvale  43.8361  -79.2056
# 17   Bloordale Gardens,Eringate,Markland Wood,Old B...  43.8038  -79.3635
# 18                     Guildwood,Morningside,West Hill  43.7785  -79.3466
# 19                                         The Beaches  43.7869   -79.386
# 20                                         Berczy Park  43.7575  -79.3747
# 21                                 Caledonia-Fairbanks  43.7891  -79.4085
# 22                                              Woburn  43.7701  -79.4085
# 23                                             Leaside  43.7528     -79.4
# 24                                  Central Bay Street  43.7827  -79.4423
# 25                                            Christie  43.7533  -79.3297
# 26                                           Cedarbrae  43.7459  -79.3522
# 27                                   Hillcrest Village  43.7259  -79.3409
# 28       Bathurst Manor,Downsview North,Wilson Heights  43.7543  -79.4423
# 29                                    Thorncliffe Park   43.768  -79.4873
# ..                                                 ...      ...       ...
# 73                                  North Toronto West  43.6938  -79.4282
# 74                   The Annex,North Midtown,Yorkville   43.689  -79.4535
# 75                               Parkdale,Roncesvalles  43.6695  -79.4226
# 76               Canada Post Gateway Processing Centre   43.669  -79.4423
# 77   Kingsview Village,Martin Grove Gardens,Richvie...  43.6479  -79.4197
# 78                                           Agincourt  43.6368  -79.4282
# 79                                          Davisville  43.7138  -79.4901
# 80                       Harbord,University of Toronto  43.6911   -79.476
# 81                                   Runnymede,Swansea  43.6732  -79.4873
# 82               Clarks Corners,Sullivan,Tam O'Shanter  43.6616  -79.4648
# 83                          Moore Park,Summerhill East   43.649  -79.4563
# 84             Chinatown,Grange Park,Kensington Market  43.6516  -79.4844
# 85   Agincourt North,L'Amoreaux East,Milliken,Steel...  43.6623  -79.3895
# 86   Deer Park,Forest Hill SE,Rathnelly,South Hill,...   43.637  -79.6158
# 87   CN Tower,Bathurst Quay,Island airport,Harbourf...  43.6627  -79.3216
# 88          Humber Bay Shores,Mimico South,New Toronto  43.6056  -79.5013
# 89   Albion Gardens,Beaumond Heights,Humbergate,Jam...  43.6024  -79.5435
# 90                                     L'Amoreaux West  43.6537  -79.5069
# 91                                            Rosedale  43.6363  -79.4985
# 92                     Stn A PO Boxes 25 The Esplanade  43.6288   -79.521
# 93                               Alderwood,Long Branch  43.6679  -79.5322
# 94                                           Northwest  43.6509  -79.5547
# 95                                         Upper Rouge  43.6435  -79.5772
# 96                          Cabbagetown,St. James Town  43.7563   -79.566
# 97               First Canadian Place,Underground city  43.7248  -79.5322
# 98         The Kingsway,Montgomery Road,Old Mill North  43.7069  -79.5182
# 99                                Church and Wellesley  43.6963  -79.5322
# 100  Business Reply Mail Processing Centre 969 Eastern  43.6889  -79.5547
# 101  Humber Bay,King's Mill Park,Kingsway Park Sout...  43.7394  -79.5884
# 102  Kingsway Park South West,Mimico NW,The Queensw...  43.7067  -79.5941
#
# [103 rows x 5 columns]

# %%
df_to_geo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103 entries, 0 to 102
# Data columns (total 5 columns):
# Postcode         103 non-null object
# Borough          103 non-null object
# Neighbourhood    103 non-null object
# Latitude         103 non-null object
# Longitude        103 non-null object
# dtypes: object(5)
# memory usage: 4.8+ KB
